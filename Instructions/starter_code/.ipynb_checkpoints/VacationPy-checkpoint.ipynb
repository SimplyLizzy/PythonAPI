# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint
#from census import Census

# Import API key
from api_keys import g_key

# # Access maps with unique API key
# gmaps.configure(api_key=g_key)

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Output File (CSV)
city_data = pd.read_csv("../output_data/cities.csv")
city_data = city_data.dropna()
city_data.head()
# Out:
#    City_ID           City Country        Date      Lat       Lng  Max Temp  \
# 0  2123814  leningradskiy      RU  1643916953  69.3833  178.4167    -12.35
# 1  2264557   ponta do sol      PT  1643916945  32.6667  -17.1000     68.00
# 2  4030556        rikitea      PF  1643917228 -23.1203 -134.9692     77.58
# 3  4020109         atuona      PF  1643916943  -9.8000 -139.0333     78.30
# 4  5880054         barrow      US  1643917228  71.2906 -156.7887    -27.38
#
#    Humidity  Cloudiness  Wind Speed
# 0        84           2        8.23
# 1        72          38        4.21
# 2        77         100       15.77
# 3        72           0       12.84
# 4        75          20        4.61

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
weather_criteria = city_data[
    (city_data['Max Temp'] < 80) & 
    (city_data['Max Temp'] >70) & 
    (city_data['Wind Speed'] < 10) & 
    (city_data['Cloudiness'] == 0)]

weather_criteria = weather_criteria.dropna()

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = weather_criteria
hotel_df['hotel_name'] = " "
hotel_df['hotel_address'] = " "
hotel_df.head()
# Out:
#      City_ID           City Country        Date      Lat       Lng  Max Temp  \
# 114  3932145          pisco      PE  1643917257 -13.7000  -76.2167     73.45
# 130   286621        salalah      OM  1643917261  17.0151   54.0924     75.29
# 160  5850554  makakilo city      US  1643917271  21.3469 -158.0858     76.28
# 178  5855927           hilo      US  1643917230  19.7297 -155.0900     76.12
# 200  5848280          kapaa      US  1643917282  22.0752 -159.3190     75.47
#
#      Humidity  Cloudiness  Wind Speed hotel_name hotel_address
# 114        73           0        6.91
# 130        73           0        1.14
# 160        59           0        5.75
# 178        64           0        4.61
# 200        71           0        1.01

# %%
for index, row in hotel_df.iterrows():
    #target = f"{row['City']}, {row['Country']}"
    #print(f"calling geocode with target: {target}")
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    params = {
        "location": f"{row['Lat']}, {row['Lng']}",
        "type": "lodging",
        "radius": "5000",
        #"rankby": "distance",
        "key": g_key
        }
    #pprint(params)
    
    places_data = requests.get(base_url, params=params).json()

    try:
        hotel_df.loc[index, 'hotel_name'] = places_data["results"][0]["name"]
        hotel_df.loc[index, 'hotel_address'] = places_data["results"][0]["vicinity"]
    
    except Exception as error:
        print(error)
        
#pprint(places_data)
# Out:
# list index out of range

# %%
hotel_df
# Out:
#      City_ID           City Country        Date      Lat       Lng  Max Temp  \
# 114  3932145          pisco      PE  1643917257 -13.7000  -76.2167     73.45
# 130   286621        salalah      OM  1643917261  17.0151   54.0924     75.29
# 160  5850554  makakilo city      US  1643917271  21.3469 -158.0858     76.28
# 178  5855927           hilo      US  1643917230  19.7297 -155.0900     76.12
# 200  5848280          kapaa      US  1643917282  22.0752 -159.3190     75.47
# 222  2358100          manga      BF  1643917289  11.6636   -1.0731     77.11
# 409  2070998      geraldton      AU  1643917254 -28.7667  114.6000     70.21
# 456  2414544         tougue      GN  1643917361  11.4667  -11.6000     71.31
# 503  3374210     sao filipe      CV  1643917374  14.8961  -24.4956     73.74
# 532  2291136      bondoukou      CI  1643917385   8.0333   -2.8000     78.69
#
#      Humidity  Cloudiness  Wind Speed  \
# 114        73           0        6.91
# 130        73           0        1.14
# 160        59           0        5.75
# 178        64           0        4.61
# 200        71           0        1.01
# 222         9           0        6.55
# 409        52           0        8.05
# 456        15           0        2.42
# 503        74           0        7.00
# 532        12           0        3.18
#
#                                          hotel_name  \
# 114                        Hotel San Isidro Oficial
# 130        HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# 160                  Marriott's Ko Olina Beach Club
# 178                             Hilo Hawaiian Hotel
# 200             Sheraton Kauai Coconut Beach Resort
# 222  Auberge du 11 décembre de la cité CNSS à Manga
# 409                       Broadwater Mariner Resort
# 456
# 503                                   Hotel Xaguate
# 532                                  Prestige Hotel
#
#                                          hotel_address
# 114                                       Calle, Pisco
# 130                                            Salalah
# 160  92-161 Waipahe Place Marriott Vacation Club Ka...
# 178                              71 Banyan Drive, Hilo
# 200                             650 Aleka Loop, Kapaʻa
# 222                                         N17, Manga
# 409                        298 Chapman Road, Geraldton
# 456
# 503                     Sao Filipe, Rua da Posto, Fogo
# 532      30 m de la présidence, route abema, Bondoukou

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
