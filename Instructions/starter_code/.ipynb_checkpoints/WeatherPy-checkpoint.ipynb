# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import os 

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
c = 0
cityid = []
foundcities = []
lat = []
lon = []
tempmax = []
humidity = []
cloudiness = []
country = []
date = []
windspeed = []

for city in cities:
    try: 
        response = requests.get(query_url + city).json()
        #pprint(response)
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        tempmax.append(response['main']['temp_max'])
        foundcities.append(city)
        cityid.append(response['id'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windspeed.append(response['wind']['speed'])
        id = response['id']
        c = c+1
        print(f"Processing Record {c} | {id}: {city}")
    except:
        print(f"Skipping: {city} not found")
        pass
#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {temp}")
# Out:
# Processing Record 1 | 2136825: isangel
# Processing Record 2 | 6111696: port-cartier
# Processing Record 3 | 3874787: punta arenas
# Skipping: taolanaro not found
# Processing Record 4 | 5855927: hilo
# Processing Record 5 | 3887127: iquique
# Processing Record 6 | 1706466: ligayan
# Processing Record 7 | 3374210: sao filipe
# Processing Record 8 | 546105: nikolskoye
# Processing Record 9 | 1015776: bredasdorp
# Processing Record 10 | 1863528: gotemba
# Processing Record 11 | 3652764: puerto ayora
# Processing Record 12 | 4030556: rikitea
# Processing Record 13 | 3372707: ribeira grande
# Processing Record 14 | 1786855: yatou
# Processing Record 15 | 5983720: iqaluit
# Processing Record 16 | 5972291: havre-saint-pierre
# Processing Record 17 | 3366880: hermanus
# Processing Record 18 | 2125693: evensk
# Processing Record 19 | 1819729: victoria
# Processing Record 20 | 2738381: lata
# Processing Record 21 | 3899695: ancud
# Processing Record 22 | 4031574: provideniya
# Processing Record 23 | 1181611: chaman
# Processing Record 24 | 2156643: mount gambier
# Processing Record 25 | 5106841: albany
# Processing Record 26 | 3831208: qaanaaq
# Processing Record 27 | 6201424: mataura
# Processing Record 28 | 2653680: carrickfergus
# Processing Record 29 | 2126123: chokurdakh
# Processing Record 30 | 4020109: atuona
# Processing Record 31 | 3405870: belem
# Skipping: doctor pedro p. pena not found
# Processing Record 32 | 1282256: hithadhoo
# Processing Record 33 | 1726449: basco
# Processing Record 34 | 5924351: clyde river
# Processing Record 35 | 5882953: aklavik
# Processing Record 36 | 4035715: avarua
# Skipping: barentsburg not found
# Processing Record 37 | 2112802: hasaki
# Processing Record 38 | 2121385: severo-kurilsk
# Processing Record 39 | 5848280: kapaa
# Processing Record 40 | 5122534: jamestown
# Processing Record 41 | 4032243: vaini
# Processing Record 42 | 2459775: bougouni
# Processing Record 43 | 6170031: tuktoyaktuk
# Processing Record 44 | 3833367: ushuaia
# Processing Record 45 | 1056899: sambava
# Processing Record 46 | 2027487: arkhara
# Processing Record 47 | 1605912: takhli
# Processing Record 48 | 1651531: ambon
# Processing Record 49 | 1519422: semey
# Processing Record 50 | 1735106: georgetown
# Processing Record 51 | 2134814: sola
# Processing Record 52 | 964432: port alfred
# Processing Record 53 | 2123814: leningradskiy
# Processing Record 54 | 3980180: frontera
# Processing Record 55 | 5367788: lompoc
# Processing Record 56 | 3470137: belmonte
# Processing Record 57 | 3466165: cidreira
# Processing Record 58 | 986717: kruisfontein
# Processing Record 59 | 3985710: cabo san lucas
# Processing Record 60 | 2063056: port augusta
# Processing Record 61 | 3430863: mar del plata
# Processing Record 62 | 934322: mahebourg
# Processing Record 63 | 1566166: thanh hoa
# Processing Record 64 | 728674: obzor
# Processing Record 65 | 2771557: mistelbach
# Processing Record 66 | 2338660: yaan
# Processing Record 67 | 3386931: tamandare
# Processing Record 68 | 1006984: east london
# Skipping: illoqqortoormiut not found
# Processing Record 69 | 2146219: hervey bay
# Processing Record 70 | 3984997: san quintin
# Processing Record 71 | 4513583: hamilton
# Processing Record 72 | 4946620: palmer
# Processing Record 73 | 5847411: kahului
# Skipping: saleaula not found
# Processing Record 74 | 1492663: serov
# Processing Record 75 | 2112309: katsuura
# Processing Record 76 | 556111: isakly
# Processing Record 77 | 4033557: tautira
# Skipping: aflu not found
# Processing Record 78 | 2075265: busselton
# Processing Record 79 | 2126199: cherskiy
# Processing Record 80 | 1688781: san pedro
# Processing Record 81 | 1852357: shimoda
# Processing Record 82 | 1269507: jaisalmer
# Processing Record 83 | 6113406: prince rupert
# Processing Record 84 | 5004792: owosso
# Processing Record 85 | 2137773: vao
# Processing Record 86 | 3418910: upernavik
# Processing Record 87 | 1649150: bengkulu
# Processing Record 88 | 2122090: pevek
# Processing Record 89 | 5554072: juneau
# Processing Record 90 | 1507390: dikson
# Processing Record 91 | 3372760: praia da vitoria
# Processing Record 92 | 2122614: okha
# Processing Record 93 | 1078553: ampanihy
# Processing Record 94 | 3356832: henties bay
# Processing Record 95 | 5880054: barrow
# Skipping: vaitupu not found
# Processing Record 96 | 3144987: beisfjord
# Processing Record 97 | 3894426: coihaique
# Processing Record 98 | 2110227: butaritari
# Processing Record 99 | 933995: souillac
# Processing Record 100 | 4726521: san patricio
# Processing Record 101 | 964420: port elizabeth
# Processing Record 102 | 3369157: cape town
# Processing Record 103 | 2377450: nouakchott
# Processing Record 104 | 6167817: torbay
# Processing Record 105 | 2128574: otaru
# Processing Record 106 | 2026023: bukachacha
# Processing Record 107 | 4003938: jimenez
# Processing Record 108 | 935215: saint-philippe
# Skipping: attawapiskat not found
# Skipping: mys shmidta not found
# Processing Record 109 | 3466704: castro
# Processing Record 110 | 2643044: margate
# Processing Record 111 | 5044290: saint anthony
# Processing Record 112 | 3443061: chuy
# Processing Record 113 | 2074865: carnarvon
# Processing Record 114 | 2126785: belaya gora
# Processing Record 115 | 5110365: broome
# Processing Record 116 | 2155415: new norfolk
# Skipping: tsihombe not found
# Processing Record 117 | 2084442: vanimo
# Skipping: buqayq not found
# Skipping: kobojango not found
# Processing Record 118 | 1737486: bintulu
# Processing Record 119 | 5380437: pacific grove
# Processing Record 120 | 5870133: nome
# Processing Record 121 | 3471451: arraial do cabo
# Processing Record 122 | 3936456: lima
# Processing Record 123 | 1797595: qinhuangdao
# Processing Record 124 | 780687: berlevag
# Processing Record 125 | 608872: makat
# Processing Record 126 | 3531368: celestun
# Processing Record 127 | 933726: hukuntsi
# Skipping: belushya guba not found
# Processing Record 128 | 3374333: praia
# Processing Record 129 | 1735634: kuching
# Processing Record 130 | 2022572: khatanga
# Processing Record 131 | 3424607: tasiilaq
# Processing Record 132 | 3913271: jorochito
# Processing Record 133 | 6089245: norman wells
# Processing Record 134 | 2088659: panguna
# Processing Record 135 | 4034551: faanui
# Processing Record 136 | 6185377: yellowknife
# Processing Record 137 | 1640902: kawalu
# Processing Record 138 | 364933: umm kaddadah
# Processing Record 139 | 3893726: constitucion
# Skipping: samusu not found
# Processing Record 140 | 3533462: acapulco
# Processing Record 141 | 1280849: kashi
# Processing Record 142 | 2258261: loubomo
# Processing Record 143 | 8079926: labuhan
# Skipping: kamenskoye not found
# Processing Record 144 | 5491487: silver city
# Processing Record 145 | 2092164: lorengau
# Processing Record 146 | 1651810: airai
# Processing Record 147 | 2126682: bilibino
# Processing Record 148 | 4231997: avera
# Processing Record 149 | 2381972: adrar
# Processing Record 150 | 5546220: saint george
# Processing Record 151 | 3393465: oros
# Processing Record 152 | 2120591: tilichiki
# Processing Record 153 | 3526756: isla mujeres
# Processing Record 154 | 3361934: saldanha
# Processing Record 155 | 2381334: atar
# Processing Record 156 | 2163355: hobart
# Processing Record 157 | 5282297: bethel
# Processing Record 158 | 687093: kozulka
# Processing Record 159 | 585236: puta
# Processing Record 160 | 1160939: iranshahr
# Skipping: mocambique not found
# Processing Record 161 | 1568770: quang ngai
# Processing Record 162 | 1255792: sonamukhi
# Processing Record 163 | 2264557: ponta do sol
# Skipping: barbar not found
# Processing Record 164 | 1486321: yar-sale
# Processing Record 165 | 2016307: solnechnyy
# Processing Record 166 | 2206939: bluff
# Processing Record 167 | 490846: solotcha
# Processing Record 168 | 2621927: frederikshavn
# Skipping: of not found
# Processing Record 169 | 1106643: quatre cocos
# Processing Record 170 | 3147104: loding
# Processing Record 171 | 1629380: ruteng
# Processing Record 172 | 2017842: pokosnoye
# Processing Record 173 | 3840300: presidencia roque saenz pena
# Processing Record 174 | 5563839: fortuna
# Processing Record 175 | 5866583: kodiak
# Processing Record 176 | 3906466: riberalta
# Processing Record 177 | 3357804: eenhana
# Processing Record 178 | 4031742: egvekinot
# Processing Record 179 | 2121126: smirnykh
# Processing Record 180 | 6165406: thompson
# Processing Record 181 | 3860443: comodoro rivadavia
# Processing Record 182 | 7647007: san carlos de bariloche
# Processing Record 183 | 1637510: loa janan
# Processing Record 184 | 5864145: homer
# Processing Record 185 | 1713558: fuerte
# Skipping: dzhusaly not found
# Processing Record 186 | 3421765: nanortalik
# Processing Record 187 | 1300466: bago
# Processing Record 188 | 2017155: saskylakh
# Processing Record 189 | 3694112: paita
# Processing Record 190 | 2657293: annan
# Processing Record 191 | 4004293: ixtapa
# Skipping: bolungarvik not found
# Processing Record 192 | 777019: vardo
# Processing Record 193 | 6111862: port hardy
# Processing Record 194 | 2013865: ust-uda
# Processing Record 195 | 1259385: port blair
# Processing Record 196 | 2208248: kaitangata
# Processing Record 197 | 5983607: inuvik
# Processing Record 198 | 3580733: bodden town
# Processing Record 199 | 127349: khorramabad
# Processing Record 200 | 6067747: matagami
# Skipping: ngukurr not found
# Processing Record 201 | 2070998: geraldton
# Skipping: toliary not found
# Processing Record 202 | 350550: qena
# Processing Record 203 | 88834: tukrah
# Processing Record 204 | 2120048: ust-nera
# Processing Record 205 | 2015686: talakan
# Processing Record 206 | 3421193: paamiut
# Processing Record 207 | 2729907: longyearbyen
# Skipping: sentyabrskiy not found
# Processing Record 208 | 3389822: salinopolis
# Processing Record 209 | 964406: port shepstone
# Processing Record 210 | 2630299: hofn
# Processing Record 211 | 3653967: muisne
# Processing Record 212 | 328709: shambu
# Processing Record 213 | 2618795: klaksvik
# Processing Record 214 | 4074736: marshall
# Processing Record 215 | 2181625: te anau
# Processing Record 216 | 2347758: bara
# Skipping: makung not found
# Processing Record 217 | 4021858: guerrero negro
# Processing Record 218 | 909887: luangwa
# Skipping: khonuu not found
# Processing Record 219 | 1070940: fenoarivo
# Processing Record 220 | 371745: kutum
# Processing Record 221 | 2127060: arman
# Processing Record 222 | 5746545: portland
# Skipping: nizhneyansk not found
# Processing Record 223 | 3105522: bereda
# Processing Record 224 | 2334652: keffi
# Processing Record 225 | 1714733: dingle
# Processing Record 226 | 3466980: caravelas
# Processing Record 227 | 1106677: bambous virieux
# Processing Record 228 | 100926: umm lajj
# Skipping: skalistyy not found
# Processing Record 229 | 3087497: radomsko
# Processing Record 230 | 2244177: velingara
# Skipping: tabiauea not found
# Processing Record 231 | 1799491: neijiang
# Processing Record 232 | 6050066: la ronge
# Processing Record 233 | 3573374: the valley
# Processing Record 234 | 1735799: sri aman
# Processing Record 235 | 3382226: camopi
# Processing Record 236 | 3883457: lebu
# Processing Record 237 | 2446796: bilma
# Skipping: haibowan not found
# Processing Record 238 | 1253102: visakhapatnam
# Processing Record 239 | 50814: wajid
# Skipping: palabuhanratu not found
# Processing Record 240 | 3393692: itarema
# Processing Record 241 | 3136690: stokmarknes
# Processing Record 242 | 3660798: alausi
# Processing Record 243 | 2030065: mandalgovi
# Processing Record 244 | 2255564: ouesso
# Processing Record 245 | 3837702: catamarca
# Processing Record 246 | 2013727: vanavara
# Processing Record 247 | 5364271: laguna
# Processing Record 248 | 2511239: san roque
# Processing Record 249 | 1283285: jumla
# Processing Record 250 | 2191562: dunedin
# Processing Record 251 | 716197: rakoczifalva
# Processing Record 252 | 3421719: narsaq
# Processing Record 253 | 945945: upington
# Processing Record 254 | 3838759: rivadavia
# Processing Record 255 | 1271215: gidam
# Processing Record 256 | 3622537: parrita
# Processing Record 257 | 244878: biltine
# Processing Record 258 | 1490256: talnakh
# Processing Record 259 | 5557293: sitka
# Processing Record 260 | 5742974: north bend
# Skipping: tumannyy not found
# Processing Record 261 | 2409914: bonthe
# Processing Record 262 | 2015217: tokur
# Processing Record 263 | 2071860: esperance
# Processing Record 264 | 1244926: hambantota
# Processing Record 265 | 964090: prieska
# Processing Record 266 | 3430443: necochea
# Processing Record 267 | 3402648: carutapera
# Processing Record 268 | 750735: besikduzu
# Processing Record 269 | 245785: abeche
# Processing Record 270 | 3520989: puerto madero
# Processing Record 271 | 3663495: manoel urbano
# Processing Record 272 | 1058381: morondava
# Processing Record 273 | 3577430: road town
# Processing Record 274 | 2514651: los llanos de aridane
# Processing Record 275 | 4031637: lavrentiya
# Processing Record 276 | 2139521: noumea
# Processing Record 277 | 3433663: gualeguay
# Processing Record 278 | 2037485: erenhot
# Processing Record 279 | 3148133: larsnes
# Processing Record 280 | 2180815: tuatapere
# Processing Record 281 | 7117100: vila
# Processing Record 282 | 5905393: bonavista
# Processing Record 283 | 286621: salalah
# Processing Record 284 | 2160735: lakes entrance
# Processing Record 285 | 3374083: bathsheba
# Processing Record 286 | 1510689: baykit
# Processing Record 287 | 2146142: townsville
# Processing Record 288 | 5850554: makakilo city
# Processing Record 289 | 1722504: burabod
# Processing Record 290 | 2015306: tiksi
# Processing Record 291 | 1489853: tazovskiy
# Processing Record 292 | 2194098: ahipara
# Processing Record 293 | 138042: damavand
# Processing Record 294 | 686090: asau
# Processing Record 295 | 3140056: sauda
# Processing Record 296 | 2126710: beringovskiy
# Processing Record 297 | 1510690: bay-khaak
# Processing Record 298 | 3579925: saint-georges
# Processing Record 299 | 3671387: puerto narino
# Processing Record 300 | 4255151: bud
# Processing Record 301 | 2109528: buala
# Processing Record 302 | 3416888: grindavik
# Processing Record 303 | 1624545: tayu
# Processing Record 304 | 2272491: zwedru
# Processing Record 305 | 337405: gambela
# Processing Record 306 | 3843123: neuquen
# Processing Record 307 | 6096551: pangnirtung
# Processing Record 308 | 2026160: borogontsy
# Processing Record 309 | 935214: saint-pierre
# Processing Record 310 | 1254133: tuensang
# Processing Record 311 | 489495: sredniy ikorets
# Processing Record 312 | 2189343: kaeo
# Skipping: khoriyion not found
# Processing Record 313 | 2063036: port lincoln
# Skipping: grazhdanskoye pervoye not found
# Skipping: grand river south east not found
# Processing Record 314 | 2015179: tommot
# Processing Record 315 | 3372964: lagoa
# Processing Record 317 | 6162951: terrace bay
# Processing Record 318 | 5830062: laramie
# Processing Record 319 | 2031964: darhan
# Processing Record 320 | 55671: kismayo
# Processing Record 321 | 1151253: phuket
# Processing Record 322 | 3155152: gravdal
# Processing Record 323 | 4703223: killeen
# Processing Record 324 | 3382867: totness
# Processing Record 325 | 3435261: concordia
# Processing Record 326 | 866062: iskateley
# Processing Record 327 | 3450288: santa cruz cabralia
# Processing Record 328 | 3355672: luderitz
# Processing Record 329 | 3671450: inirida
# Processing Record 330 | 3943957: chilca
# Processing Record 331 | 3468789: buritama
# Processing Record 332 | 116406: semirom
# Processing Record 333 | 86049: jalu
# Processing Record 334 | 3351024: caluquembe
# Processing Record 335 | 2128975: nemuro
# Processing Record 336 | 1515029: ulaangom
# Processing Record 337 | 1337619: ugoofaaru
# Processing Record 338 | 1850091: tomioka
# Processing Record 339 | 1501377: kungurtug
# Processing Record 340 | 53157: qandala
# Processing Record 341 | 6180550: whitehorse
# Processing Record 342 | 2629833: husavik
# Processing Record 343 | 2520645: cabra
# Processing Record 344 | 452949: udomlya
# Processing Record 345 | 1494955: pioner
# Processing Record 346 | 3489555: maroon town
# Processing Record 347 | 1226260: trincomalee
# Processing Record 348 | 80509: bardiyah
# Processing Record 349 | 1806466: guangyuan
# Skipping: maghama not found
# Processing Record 350 | 1026014: tete
# Processing Record 351 | 3421319: nuuk
# Processing Record 352 | 286245: sur
# Skipping: boljarovo not found
# Processing Record 353 | 1052373: beira
# Processing Record 354 | 2212775: sabha
# Processing Record 355 | 2027968: aldan
# Processing Record 356 | 3489440: morant bay
# Processing Record 357 | 3379316: lethem
# Processing Record 358 | 3981391: tomatlan
# Processing Record 359 | 3530367: comitan
# Processing Record 360 | 3674292: mosquera
# Processing Record 361 | 4362001: mayo
# Processing Record 362 | 4047434: russell
# Processing Record 363 | 6125862: roblin
# Processing Record 364 | 3456285: niquelandia
# Processing Record 365 | 2441530: madaoua
# Processing Record 366 | 2093685: kokopo
# Processing Record 367 | 4954611: watertown
# Processing Record 368 | 3869716: tocopilla
# Skipping: cheuskiny not found
# Processing Record 369 | 1502073: krasnoselkup
# Processing Record 370 | 6100799: pemberton
# Processing Record 371 | 64814: bandarbeyla
# Processing Record 372 | 1563281: tuy hoa
# Processing Record 373 | 2020838: lensk
# Processing Record 374 | 1682100: tilik
# Processing Record 375 | 1489138: tselinnoye
# Processing Record 376 | 2109701: auki
# Processing Record 377 | 1633419: padang
# Processing Record 378 | 3460064: jatai
# Processing Record 379 | 3984078: santa maria del oro
# Processing Record 380 | 89113: ajdabiya
# Processing Record 381 | 2266895: machico
# Processing Record 382 | 2123628: magadan
# Processing Record 383 | 651299: mustasaari
# Processing Record 384 | 3387625: simoes
# Processing Record 385 | 6078372: moose factory
# Processing Record 386 | 3839307: rawson
# Processing Record 387 | 187968: malindi
# Processing Record 388 | 2033413: cuiluan
# Processing Record 389 | 1037125: montepuez
# Processing Record 390 | 2129766: kamiiso
# Processing Record 391 | 470905: vuktyl
# Processing Record 392 | 6453316: tromso
# Processing Record 393 | 136702: dehloran
# Processing Record 394 | 1788852: xining
# Processing Record 395 | 5942547: drayton valley
# Processing Record 396 | 2276492: harper
# Processing Record 397 | 2108857: gizo
# Processing Record 398 | 5339663: coronado
# Processing Record 399 | 566384: desnogorsk
# Processing Record 400 | 10722858: svetlogorsk
# Processing Record 401 | 2455290: kidal
# Processing Record 402 | 3674676: mitu
# Processing Record 403 | 1808857: hanzhong
# Processing Record 404 | 2513947: melilla
# Processing Record 405 | 962367: richards bay
# Processing Record 406 | 1862505: hirara
# Processing Record 407 | 2176639: batemans bay
# Processing Record 408 | 149854: sirari
# Processing Record 409 | 2641434: northam
# Processing Record 410 | 2013918: ust-maya
# Processing Record 411 | 1803936: wuwei
# Skipping: umzimvubu not found
# Processing Record 412 | 161616: balkanabat
# Processing Record 413 | 6201197: lahij
# Processing Record 414 | 3422683: kangaatsiaq
# Processing Record 415 | 3670856: restrepo
# Processing Record 416 | 4721703: raymondville
# Processing Record 417 | 3420846: qaqortoq
# Processing Record 418 | 1687534: santo tomas
# Processing Record 419 | 3919720: colquechaca
# Skipping: navapur not found
# Processing Record 420 | 4723422: rockport
# Processing Record 421 | 1804540: langfang
# Processing Record 422 | 2303611: axim
# Processing Record 423 | 2171722: charters towers
# Processing Record 424 | 5866063: kenai
# Processing Record 425 | 1264688: lunglei
# Processing Record 426 | 2294915: takoradi
# Processing Record 427 | 304183: bayir
# Processing Record 428 | 3939761: hualmay
# Processing Record 429 | 1607976: pattani
# Processing Record 430 | 1510030: biskamzha
# Processing Record 431 | 857690: moskovskiy
# Processing Record 432 | 2377457: nouadhibou
# Processing Record 433 | 4616470: crossville
# Processing Record 434 | 1267390: kavaratti
# Processing Record 435 | 921786: mitsamiouli
# Processing Record 436 | 2057087: kupang
# Skipping: phan rang not found
# Processing Record 437 | 1525798: balkhash
# Processing Record 438 | 3698304: chimbote
# Processing Record 439 | 2013399: vikhorevka
# Processing Record 440 | 5493811: taos
# Skipping: karauzyak not found
# Processing Record 441 | 1277527: balotra
# Processing Record 442 | 69500: zabid
# Processing Record 443 | 3404817: breves
# Skipping: yunjinghong not found
# Processing Record 444 | 556279: inzer
# Processing Record 445 | 1131162: panjab
# Processing Record 446 | 158825: izazi
# Processing Record 447 | 6179652: weyburn
# Processing Record 448 | 556268: ostrovnoy
# Processing Record 449 | 2033467: yanji
# Processing Record 450 | 5973108: hearst
# Processing Record 451 | 4315067: ascension
# Processing Record 452 | 458972: karsava
# Processing Record 453 | 3842881: nueve de julio
# Processing Record 454 | 3385899: tutoia
# Processing Record 455 | 638936: rovaniemi
# Processing Record 456 | 2214846: misratah
# Skipping: mullaitivu not found
# Processing Record 457 | 7671223: kloulklubed
# Processing Record 458 | 898947: senanga
# Skipping: marcona not found
# Processing Record 459 | 2984701: quimper
# Processing Record 460 | 4722062: redwater
# Processing Record 461 | 3423146: ilulissat
# Processing Record 462 | 569295: cheremukhovo
# Processing Record 463 | 1513491: komsomolskiy
# Processing Record 464 | 3668605: santa marta
# Processing Record 465 | 1498161: muzhi
# Processing Record 466 | 1024312: mocuba
# Processing Record 467 | 778707: mehamn
# Processing Record 468 | 487928: novikovo
# Processing Record 469 | 1303406: nyaunglebin
# Processing Record 470 | 2027806: amazar
# Processing Record 471 | 1163054: turbat
# Processing Record 472 | 2027316: ayan
# Processing Record 473 | 5515743: guymon
# Processing Record 474 | 5710360: winnemucca
# Processing Record 475 | 3654541: macas
# Processing Record 476 | 2439812: say
# Processing Record 477 | 1786538: yining
# Processing Record 478 | 2983488: riom
# Skipping: amderma not found
# Processing Record 479 | 3380290: sinnamary
# Processing Record 480 | 1631637: pemangkat
# Processing Record 481 | 2158767: mareeba
# Processing Record 482 | 2240449: luanda
# Skipping: ahumada not found
# Processing Record 483 | 1242110: kalmunai
# Processing Record 484 | 1337607: kudahuvadhoo
# Processing Record 485 | 3994469: ojinaga
# Processing Record 486 | 1712961: gigmoto
# Processing Record 487 | 103630: najran
# Processing Record 488 | 2039557: khasan
# Processing Record 489 | 3460531: ituacu
# Processing Record 490 | 1734586: taiping
# Processing Record 491 | 4805404: fairmont
# Processing Record 492 | 259289: corinto
# Processing Record 493 | 2255285: sibiti
# Processing Record 494 | 464790: zapolyarnyy
# Processing Record 495 | 1263942: manavalakurichi
# Processing Record 496 | 627907: gomel
# Processing Record 497 | 3933024: paramonga
# Processing Record 498 | 1856392: muroto
# Processing Record 499 | 3832899: viedma
# Skipping: satitoa not found
# Processing Record 500 | 2964496: dunmanway
# Skipping: tarudant not found
# Processing Record 501 | 778362: oksfjord
# Processing Record 502 | 1500957: kyzyl-mazhalyk
# Processing Record 503 | 1254046: tura
# Skipping: karkaralinsk not found
# Processing Record 504 | 1495385: pelym
# Processing Record 505 | 3561408: el cobre
# Processing Record 506 | 2090990: mendi
# Processing Record 507 | 584716: xanlar
# Processing Record 508 | 5949601: eston
# Processing Record 509 | 2122605: okhotsk
# Processing Record 510 | 3115824: muros
# Processing Record 511 | 645765: muhos
# Processing Record 512 | 3451399: ribas do rio pardo
# Processing Record 513 | 3870282: talcahuano
# Processing Record 514 | 2823398: teterow
# Processing Record 515 | 3141667: roald
# Processing Record 516 | 2177069: ballina
# Processing Record 517 | 565778: dobryanka
# Processing Record 518 | 2637762: skegness
# Processing Record 519 | 57000: hobyo
# Processing Record 520 | 1681936: cagliliog
# Processing Record 521 | 480884: bolshoye nagatkino
# Processing Record 522 | 5919850: chapais
# Processing Record 523 | 2122262: palana
# Processing Record 524 | 3038789: abbeville
# Processing Record 525 | 3517970: pochutla
# Processing Record 526 | 1519030: shu
# Processing Record 527 | 5251040: dunn
# Processing Record 528 | 1520253: zharkent
# Processing Record 529 | 3572906: andros town
# Processing Record 530 | 2021017: kysyl-syr
# Processing Record 531 | 1529484: hami
# Processing Record 532 | 108410: riyadh
# Processing Record 533 | 3988392: rosarito
# Processing Record 534 | 3385077: conde
# Processing Record 535 | 174726: saravan
# Processing Record 536 | 3939168: huarmey
# Processing Record 537 | 1175296: kalat
# Processing Record 538 | 4005539: guadalajara
# Processing Record 539 | 1817858: babu
# Processing Record 540 | 2023286: kalga
# Skipping: wulanhaote not found
# Skipping: ziyamet not found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_dict = pd.DataFrame({
                "City_ID": cityid,
                "City": foundcities,
                "Country": country,
                "Date": date,
                "Lat": lat,
                "Lng": lon,
                "Max Temp": tempmax,
                "Humidity": humidity,
                "Cloudiness": cloudiness,
                "Wind Speed": windspeed
                })

output_path = os.path.join("..","output_data","cities.csv")
city_dict.to_csv(output_path, index=False, header=True)

# %%
city_data = pd.read_csv("../output_data/cities.csv")
city_data = city_data.dropna()
len(city_data)
# Out:
# 537

# %%
city_data.describe()
# Out:
#             City_ID          Date         Lat         Lng    Max Temp  \
# count  5.370000e+02  5.370000e+02  537.000000  537.000000  537.000000
# mean   2.698821e+06  1.643762e+09   22.114618   16.863728    9.022309
# std    1.693208e+06  1.066972e+02   32.863407   90.939466   17.568296
# min    5.081400e+04  1.643761e+09  -54.800000 -179.166700  -38.710000
# 25%    1.510690e+06  1.643762e+09   -2.924800  -66.100000   -4.060000
# 50%    2.181625e+06  1.643762e+09   26.161500   22.347900   15.140000
# 75%    3.670856e+06  1.643762e+09   50.599400  100.335400   23.790000
# max    1.072286e+07  1.643762e+09   78.218600  179.316700   32.940000
#
#          Humidity  Cloudiness  Wind Speed
# count  537.000000  537.000000  537.000000
# mean    73.748603   57.165736    3.613557
# std     21.202694   41.618834    2.712178
# min     11.000000    0.000000    0.000000
# 25%     64.000000   14.000000    1.590000
# 50%     78.000000   75.000000    3.010000
# 75%     90.000000  100.000000    5.040000
# max    100.000000  100.000000   18.520000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
city_data.loc[city_data["Humidity"] > 100]
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_data = city_data.drop(city_data.loc[city_data["Humidity"]>100].index, inplace = False)
clean_data.head()
# Out:
#    City_ID          City Country        Date      Lat       Lng  Max Temp  \
# 0  2136825       isangel      VU  1643762082 -19.5500  169.2667     31.06
# 1  6111696  port-cartier      CA  1643762082  50.0334  -66.8654    -16.81
# 2  3874787  punta arenas      CL  1643761983 -53.1500  -70.9167      9.06
# 3  5855927          hilo      US  1643762083  19.7297 -155.0900     24.58
# 4  3887127       iquique      CL  1643761871 -20.2208  -70.1431     20.37
#
#    Humidity  Cloudiness  Wind Speed
# 0        79          75        1.54
# 1        89         100        0.75
# 2        61          40        6.17
# 3        84          38        0.89
# 4        76           5        2.12

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs (or svgs)

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_data["Lat"], clean_data["Max Temp"], c = "yellowgreen")
plt.title("City Latitude vs. Max Temperature")

plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

plt.savefig("../Images/Lat_vs_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_data["Lat"], clean_data["Humidity"], c="yellowgreen")
plt.title("City Latitude vs. Humidity")

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("../Images/Lat_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_data["Lat"], clean_data["Cloudiness"],c="yellowgreen")
plt.title("City Latitude vs. Cloudiness")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("../Images/Lat_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_data["Lat"], clean_data["Wind Speed"], c = "yellowgreen")
plt.title("City Latitude vs. Wind Speed")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("../Images/Lat_vs_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_temp_data = clean_data.loc[clean_data["Lat"] >= 0]

x_values = north_temp_data["Lat"]
y_values = north_temp_data["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(" ")
print(f"The r-value is: {rvalue}")
print(" ")

plt.scatter(x_values,y_values,c="yellowgreen")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")
plt.title("Northern Hemisphere: Max Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid(True)

plt.savefig("../Images/North_Lat_vs_Temp.png")
plt.show()
# Out:
#
# The r-value is: -0.8589005161574627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_temp_data = clean_data.loc[clean_data["Lat"] < 0]

x_values = south_temp_data["Lat"]
y_values = south_temp_data["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# y = m(Slope)x + b (intecept)
regress_values = x_values * slope + intercept
                                     
# we get a list of regrss values that creates a line
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(" ")
print(f"The r-value is: {rvalue}")
print(" ")

plt.scatter(x_values,y_values, color="yellowgreen")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")
plt.title("Southern Hemisphere: Max Temperature vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid(True)

plt.savefig("../Images/South_Lat_vs_Temp.png")
plt.show()
# Out:
#
# The r-value is: 0.41327269050209187

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_humid_data = clean_data.loc[clean_data["Lat"] >= 0]

x_values = north_humid_data["Lat"]
y_values = north_humid_data["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# y = m(Slope)x + b (intecept)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(" ")
print(f"The r-value is: {rvalue}")
print(" ")

plt.scatter(x_values,y_values, color = "yellowgreen")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.title("Northern Hemisphere: Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("../Images/North_Lat_vs_Humidity.png")
plt.show()
# Out:
#
# The r-value is: 0.364652153260812

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_humid_data = clean_data.loc[clean_data["Lat"] < 0]

x_values = south_humid_data["Lat"]
y_values = south_humid_data["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# y = m(Slope)x + b (intecept)
regress_values = x_values * slope + intercept

print(" ")
print(f"The r-value is: {rvalue}")
print(" ")

# we get a list of regrss values that creates a line
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,c="yellowgreen")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,22),fontsize=15,color="red")
plt.title("Southern Hemisphere: Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("../Images/South_Lat_vs_Humidity.png")
plt.show()
# Out:
#
# The r-value is: 0.4036256749437479

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_cloudi_data = clean_data.loc[clean_data["Lat"] >= 0]

x_values = north_cloudi_data["Lat"]
y_values = north_cloudi_data["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# y = m(Slope)x + b (intecept)
regress_values = x_values * slope + intercept

print(" ")
print(f"The r-value is: {rvalue}")
print(" ")

# we get a list of regrss values that creates a line
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,c="yellowgreen")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-3,25),fontsize=15,color="red")
plt.title("Northern Hemisphere: Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("../Images/North_Lat_vs_Cloudiness.png")
plt.show()
# Out:
#
# The r-value is: 0.3143778706734913

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_cloudi_data = clean_data.loc[clean_data["Lat"] < 0]

x_values = south_cloudi_data["Lat"]
y_values = south_cloudi_data["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# y = m(Slope)x + b (intecept)
regress_values = x_values * slope + intercept

print(" ")
print(f"The r-value is: {rvalue}")
print(" ")

# we get a list of regrss values that creates a line
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values, c="yellowgreen")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-49,24),fontsize=15,color="red")
plt.title("Southern Hemisphere: Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("../Images/South_Lat_vs_Cloudiness.png")
plt.show()
# Out:
#
# The r-value is: 0.2248680290502951

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_wind_data = clean_data.loc[clean_data["Lat"] >= 0]

x_values = north_wind_data["Lat"]
y_values = north_wind_data["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# y = m(Slope)x + b (intecept)
regress_values = x_values * slope + intercept

print(" ")
print(f"The r-value is: {rvalue}")
print(" ")

# we get a list of regrss values that creates a line
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values,c="yellowgreen")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.title("Northern Hemisphere: Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("../Images/North_Lat_vs_WindSpeed.png")
plt.show()
# Out:
#
# The r-value is: 0.05564946869068244

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_wind_data = clean_data.loc[clean_data["Lat"] < 0]

x_values = south_wind_data["Lat"]
y_values = south_wind_data["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(" ")
print(f"The r-value is: {rvalue}")
print(" ")

plt.scatter(x_values,y_values, c="yellowgreen")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-26,43),fontsize=15,color="red")
plt.title("Southern Hemisphere: Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("../Images/South_Lat_vs_WindSpeed.png")
plt.show()
# Out:
#
# The r-value is: -0.233430810815115
